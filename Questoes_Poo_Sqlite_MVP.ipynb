# %% [markdown]
# 1️⃣ Como a POO pode facilitar a escalabilidade e modularidade do seu MVP da padaria? Explique com exemplos práticos da sua estrutura de código.
# ►modularidade, precaução com duplicidade, segurança...oq ue vc acha??
#
# 2️⃣ Como a integração entre SQLite e POO pode automatizar a atualização do estoque conforme os produtos são vendidos? Desenvolva um fluxo lógico explicando essa relação.
# ►a integração entre poo e sqlite irá permitir escabilidade, modularização persistencia de dados em decorrencia de operações ocorrenmdo em tempo real no cenario da padaria.
#
#
# 3️⃣ Quais são as vantagens e desafios de usar um banco de dados relacional para gerenciar seu estoque de produtos?
# ► a vantagem de um banco de dados relacionais se deve ao fato de se permitir acesso a multiplas outros dados em outras tabelas, e o desafio se dá na logica eficiente que pode - A PRINCIPIO, parecer complexo e bicho papão, mas se estudadas e compreendidas será suave e harmoniosa, e o dominio de FOREIGN KEYS  com INNER JOIN e JOIN permitirão esta relacionais em multiplas camadas
#
# 4️⃣ Explique como você organizaria suas classes em Python para representar os sub-estoques e as opções de venda da padaria.
# ►penso assim, classe pai  contendo todos os subestoques( ai veremos se os unificamos ou não) subclasses que herdam e aplicam suas personalizações unicas pólimorfismo...
#
# 5️⃣ No contexto do seu MVP, qual seria a melhor estratégia para estruturar as consultas SQL, garantindo eficiência e desempenho?
# ► ir já criando as estrturas dos subestoques todas padronizadas e a criação do cardapio que conterá uma estrtutura e mapeamento de produção deste item a venda e que é feita a partir dos insumos dos subestoques em porções exatas para a confecção deste prato, lanche, bebida...
#
#
# 6️⃣ Como o princípio de encapsulamento pode evitar modificações indesejadas nos dados do sistema?
#
#
#
# 7️⃣ Qual seria a abordagem correta para implementar herança entre diferentes tipos de produtos da padaria?
#
#
# 8️⃣ Como evitar anomalias de concorrência ao atualizar estoque e pedidos simultaneamente no banco de dados SQLite?
#
#
# 9️⃣ Quais seriam as melhores chaves primárias e estrangeiras para relacionar os produtos do estoque com os itens do cardápio?
#
#
# 🔟 Qual seria um bom modelo de relacionamento entre tabelas e classes POO dentro do sistema?

# %% [markdown]
# 📌 Seção 2: Múltipla Escolha (10 questões)
#
#
# 1️⃣ Qual destes métodos não é adequado para persistência de dados em SQLite?
#
# - commit()
# - rollback()
# - SELECT * FROM produtos WHERE estoque > 0
# - close()
#
#
# 2️⃣ Qual dos seguintes conceitos não pertence à POO?
#
# - Herança
# - Encapsulamento
# - Threads
# - Polimorfismo
#
#
# 3️⃣ Em SQLite, qual a função da cláusula FOREIGN KEY?
#
# - Criar uma chave primária
# - Relacionar dados entre tabelas
# - Definir valores padrão
# - Atualizar tabelas automaticamente
#
#
# 4️⃣ Qual das opções é a melhor abordagem para recuperar um único registro do banco?
#
# - cursor.fetchone()
# - cursor.fetchall()
# - cursor.commit()
# - SELECT * FROM produtos
#
#
# 5️⃣ Como uma classe base pode ser usada para definir produtos da padaria?
#
# - Criando uma tabela separada para cada tipo de produto
# - Usando herança e métodos genéricos
# - Escrevendo um script SQL separado para cada item
# - Fazendo todas as consultas no código, sem relação entre as tabelas
#
#
# 6️⃣ O que significa a cláusula PRAGMA foreign_keys = ON em SQLite?
#
# - Ativa a verificação de relações entre tabelas
# - Define tipos de dados em colunas
# - Apaga registros automaticamente
# - Evita conflitos de conexão
#
#
# 7️⃣ Qual dessas não é uma boa prática ao manipular bancos de dados em Python?
#
# - Fechar conexões corretamente
# - Usar transações para evitar inconsistências
# - Fazer commits frequentemente
# - Executar consultas sem validação de dados
#
#
# 8️⃣ No seu MVP, qual classe ou método seria responsável por calcular os ingredientes consumidos a partir dos pedidos?
#
# - Pedido.calcular_insumos()
# - Estoque.verificar_disponibilidade()
# - sqlite3.connect()
# - SQLAlchemy.Table
#
#
# 9️⃣ Qual das alternativas representa um bom modelo de relacionamento entre estoque e vendas?
#
# - Criar tabelas separadas, sem conexão entre elas
# - Usar chaves estrangeiras para vincular ingredientes aos produtos
# - Salvar tudo em um arquivo JSON externo
# - Manter todas as informações dentro de uma única tabela
#
#
# 🔟 Em POO, qual é a função da abstração?
#
# - Esconder detalhes internos e permitir interações mais intuitivas
# - Tornar o código mais difícil de entender
# - Separar dados em diferentes tabelas do SQLite
# - Criar múltiplas instâncias de um objeto

# %% [markdown]
# 📌 Seção 3: Verdadeiro ou Falso (10 questões)
#
# 1️⃣ POO é útil para organizar o código, mas não melhora a reutilização. (F/V)
#
#
# 2️⃣ No SQLite, usar índices em colunas pode acelerar as consultas. (F/V)
#
#
# 3️⃣ Em Python, um método estático é utilizado quando a função não precisa
# acessar atributos da classe. (F/V)
#
#
# 4️⃣ O comando ROLLBACK desfaz todas as operações da última transação no banco de dados. (F/V)
#
#
# 5️⃣ Em POO, um objeto pode instanciar diferentes classes ao mesmo tempo. (F/V)
#
#
# 6️⃣ O SQLite não suporta relações entre tabelas através de chaves estrangeiras. (F/V)
#
#
# 7️⃣ O polimorfismo permite que métodos com o mesmo nome tenham comportamentos diferentes em classes derivadas. (F/V)
#
#
# 8️⃣ Em SQLite, o comando DELETE remove registros e libera o espaço ocupado imediatamente. (F/V)
#
#
# 9️⃣ O modelo do seu MVP pode ser estruturado sem relacionamentos entre tabelas. (F/V)
#
#
# 🔟 A modularização da lógica do sistema em classes POO melhora a organização e reutilização do código. (F/V)

# %% [markdown]
# 📌 Seção 4: Interpretação de Código (10 questões)
# (Analisando scripts e explicando linha a linha)
#
# 1️⃣ Explique cada linha deste código:
#
# import sqlite3
#
# class Estoque:
#     def __init__(self, conexao):
#         self.conexao = conexao
#         self.cursor = self.conexao.cursor()
#
#     def verificar_disponibilidade(self, produto_id):
#         query = "SELECT quantidade FROM sub_estoque WHERE produto_id = ?"
#         self.cursor.execute(query, (produto_id,))
#         resultado = self.cursor.fetchone()
#         return resultado[0] > 0 if resultado else False
#
#
# 2️⃣ Qual seria a melhor abordagem para otimizar consultas SQL dentro da classe Pedido?
#
# 3️⃣ O código abaixo apresenta um problema estrutural. Qual é e como corrigi-lo?
# class Produto:
#     def __init__(self, nome, preco, estoque):
#         self.nome = nome
#         self.preco = preco
#         self.estoque = estoque
#
#     def vender(self, quantidade):
#         self.estoque -= quantidade
#         print(f"{quantidade} unidades de {self.nome} vendidas!")
#
#
#
# 💡 Essas 50 questões vão te aprofundar nos conceitos, boas práticas e desafios reais do MVP da padaria! 🔥
